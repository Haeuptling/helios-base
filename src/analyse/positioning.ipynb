# %%
import matplotlib.pyplot as plt

# base
data = {
        "ball": {"x": -11.00, "y": -11.00},
    "1": {"x": 0.00, "y": 4.00},
    "2": {"x": 0.00, "y": -4.00},
    "3": {"x": -12.00, "y": 36.00},
    "4": {"x": -15.00, "y": 36.00},
    "5": {"x": -18.00, "y": 36.00},
    "6": {"x": -21.00, "y": 36.00},
    "7": {"x": -24.00, "y": 36.00},
    "8": {"x": -27.00, "y": 36.00},
    "9": {"x": -30.00, "y": 36.00},
    "10": {"x": -33.00, "y": 36.00},
    "11": {"x": -36.00, "y": 36.00}
}



# v_7
# data = {
#       "ball" : { "x" : -40.00, "y" : 0.00 }, 
#          "1" : { "x" : -50.00, "y" : 0.00 }, 
#          "2" : { "x" : -40.00, "y" : 15.00 },
#          "3" : { "x" : -40.00, "y" : -15.00 }, 
#          "4" : { "x" : -30.00, "y" : 0.00 }, 
#          "5" : { "x" : -20.00, "y" : 20.00 }, 
#          "6" : { "x" : -20.00, "y" : -20.00 }, 
#          "7" : { "x" : -10.00, "y" : 0.00 },
#          "8" : { "x" : -5.00, "y" : 10.00 }, 
#          "9" : { "x" : -5.00, "y" : -10.00 },
#         "10" : { "x" : 0.00, "y" : 15.00 }, 
#         "11" : { "x" : 0.00, "y" : -15.00 } 
#     }
    
# data = {
#       "ball" : { "x" : 0.00, "y" : 0.00 },
#          "1" : { "x" : -50.00, "y" : 0.00 }, 
#          "2" : { "x" : -40.00, "y" : 20.00 }, 
#          "3" : { "x" : -40.00, "y" : -20.00 }, 
#          "4" : { "x" : -20.00, "y" : 0.00 }, 
#          "5" : { "x" : -10.00, "y" : 15.00 }, 
#          "6" : { "x" : -10.00, "y" : -15.00 }, 
#          "7" : { "x" : 0.00, "y" : 0.00 }, 
#          "8" : { "x" : 10.00, "y" : 10.00 },
#          "9" : { "x" : 10.00, "y" : -10.00 },
#         "10" : { "x" : 15.00, "y" : 5.00 }, 
#         "11" : { "x" : 15.00, "y" : -5.00 } 
#     }

# data = {
#       "ball" : { "x" : 40.00, "y" : 0.00 }, 
#          "1" : { "x" : -50.00, "y" : 0.00 }, 
#          "2" : { "x" : -30.00, "y" : 15.00 }, 
#          "3" : { "x" : -30.00, "y" : -15.00 }, 
#          "4" : { "x" : -10.00, "y" : 0.00 }, 
#          "5" : { "x" : 0.00, "y" : 20.00 }, 
#          "6" : { "x" : 0.00, "y" : -20.00 }, 
#          "7" : { "x" : 20.00, "y" : 0.00 },
#          "8" : { "x" : 25.00, "y" : 10.00 }, 
#          "9" : { "x" : 25.00, "y" : -10.00 }, 
#         "10" : { "x" : 30.00, "y" : 5.00 }, 
#         "11" : { "x" : 30.00, "y" : -5.00 } 
#     }

# v_2

# data = {
#       "ball": { "x": -11.00, "y": -11.00 },
#       "1": { "x": 20.00, "y": 6.00 },
#       "2": { "x": 20.00, "y": -6.00 },
#       "3": { "x": 15.00, "y": 20.00 },
#       "4": { "x": 15.00, "y": -20.00 },
#       "5": { "x": 10.00, "y": 10.00 },
#       "6": { "x": 10.00, "y": -10.00 },
#       "7": { "x": 5.00, "y": 5.00 },
#       "8": { "x": 5.00, "y": -5.00 },
#       "9": { "x": -5.00, "y": 15.00 },
#       "10": { "x": -5.00, "y": -15.00 },
#       "11": { "x": -10.00, "y": 0.00 }
#     }
    
    
    

# Spielfeld 
plt.figure(figsize=(10, 6))
plt.axhline(0, color='black', linewidth=0.5)  
plt.axvline(0, color='black', linewidth=0.5) 

# Frame
plt.plot([-52.5, 52.5, 52.5, -52.5, -52.5], [-34, -34, 34, 34, -34], color="green")

# Spieler, Ball
for key, value in data.items():
    if key == "ball":
        plt.scatter(value["x"], value["y"], color="red", label="Ball", s=100)
    else:
        plt.scatter(value["x"], value["y"], color="blue", label=f"Player " if int(key) == 1 else "", s=50)
        plt.text(value["x"], value["y"], key, color="black", fontsize=8, ha="center", va="center")

plt.xlim(-55, 55)
plt.ylim(-40, 40)
plt.gca().set_aspect("equal", adjustable="box")

plt.title("Player positions")
plt.legend(loc="upper right")
plt.xlabel("x ")
plt.ylabel("y ")

plt.grid(True, linestyle="--", linewidth=0.5)
plt.show()
